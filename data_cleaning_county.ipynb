# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
import sklearn
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 100)

# %%
# encoding specified to avoid errors in reading files

area = pd.read_csv('data/DEC_10_SF1_GCTPH1.US05PR_with_ann.csv', encoding = "ISO-8859-1")
unemp = pd.read_csv('data/Unemployment.csv')
educ = pd.read_excel('data/Education.xls')
pops = pd.read_excel('data/PopulationEstimates.xls')
poverty = pd.read_csv('data/PovertyEstimates.csv')
proptax = pd.read_excel('data/state_prop_taxes.xlsx')
homes = pd.read_csv('data/County_Zhvi_AllHomes.csv', encoding = "ISO-8859-1")
aws_loc = pd.read_excel('data/amazon-warehouses.xlsx')
walmart_loc = pd.read_csv('data/walmart-warehouses.csv')

# %%
# Trim area dataset

def split_state(x):
    if len(x.split()) >= 5:
        return x.split()[3]
    else:
        return np.nan

# %%
area['state'] = area['Geographic area'].apply(split_state)
columns = ['Geographic area.1','state','area_sq_mi']
area_df = area[columns]
area_df = area_df.rename(columns = {'Geographic area.1':'county'})

# %%
print(area_df.shape)
area_df.head()
# Out:
# (3274, 3)
#            county    state  area_sq_mi
# 0   United States      NaN  3796742.23
# 1         Alabama      NaN    52420.07
# 2  Autauga County  Alabama      604.39
# 3  Baldwin County  Alabama     2027.31
# 4  Barbour County  Alabama      904.52

# %%
# Trim unemployment dataset
columns = ['Area_name','State','Unemployment_rate_2010','Unemployment_rate_2017']
unemp_df = unemp[columns]

unemp_df['unemployment_change'] = (unemp_df.Unemployment_rate_2017 - unemp_df.Unemployment_rate_2010)
unemp_df['Area_name'] = unemp_df.Area_name.apply(lambda x: x.split(',')[0])
unemp_df.drop('Unemployment_rate_2010',axis=1,inplace=True)
unemp_df = unemp_df.rename(columns = {'Unemployment_rate_2017':'unemployment_rate','Area_name': 'county', 'State':'state'})

print(unemp_df.shape)
unemp_df.head()
# Out:
# (3194, 4)
# /Users/flatironschooldc2/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/flatironschooldc2/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#            county state  unemployment_rate  unemployment_change
# 0  Autauga County    AL                3.9                 -5.0
# 1  Baldwin County    AL                4.1                 -5.9
# 2  Barbour County    AL                5.8                 -6.5
# 3     Bibb County    AL                4.4                 -7.0
# 4   Blount County    AL                4.0                 -5.8

# %%
# Trim education dataset
# Will need to exclude one column/engineer due to perfect multicollinearity
columns = ['Area name', 'State', 'less_HS_2013-17', 'HS_2013-17','college_associates_2013-17', 'bachelors_2013-17']
educ_df = educ[columns]
educ_df = educ_df.rename(columns = {'less_HS_2013-17':'less_high_school', 'HS_2013-17': 'high_school','college_associates_2013-17': 'college_or_associates', 'bachelors_2013-17': 'bachelors'})

print(educ_df.shape)
educ_df.head()
# Out:
# (3283, 6)
#         Area name State  less_high_school  high_school  college_or_associates  \
# 0   United States    US              12.7         27.3                   29.1
# 1         Alabama    AL              14.7         30.9                   29.9
# 2  Autauga County    AL              12.3         33.6                   29.1
# 3  Baldwin County    AL               9.8         27.8                   31.7
# 4  Barbour County    AL              26.9         35.5                   25.5
#
#    bachelors
# 0       30.9
# 1       24.5
# 2       25.0
# 3       30.7
# 4       12.0

# %%
# Trim population dataset
columns = ['Area_Name', 'State', 'POP_ESTIMATE_2010', 'POP_ESTIMATE_2017', 'R_INTERNATIONAL_MIG_2017', 'R_NET_MIG_2017']
pop_df = pops[columns]

pop_df['pop_growth'] = (pop_df.POP_ESTIMATE_2017 - pop_df.POP_ESTIMATE_2010)*100/pop_df.POP_ESTIMATE_2010
pop_df.drop('POP_ESTIMATE_2010', axis=1, inplace=True)
pop_df = pop_df.rename(columns = {'POP_ESTIMATE_2017':'population', 'R_INTERNATIONAL_MIG_2017': 'int_migration_rate', 'R_NET_MIG_2017': 'net_migration_rate'})

print(pop_df.shape)
pop_df.head()
# Out:
# (3194, 6)
# /Users/flatironschooldc2/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/flatironschooldc2/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#         Area_Name State  population  int_migration_rate  net_migration_rate  \
# 0   United States    US   325147121                 NaN                 NaN
# 1         Alabama    AL     4875120            0.655040            1.079070
# 2  Autauga County    AL       55443           -0.036139            1.029950
# 3  Baldwin County    AL      212619            0.537672           22.534622
# 4  Barbour County    AL       25158            0.470801          -25.030896
#
#    pop_growth
# 0    5.114679
# 1    1.873848
# 2    1.258356
# 3   16.114816
# 4   -7.947311

# %%
# Trim poverty dataset
columns = ['Area_Name','State','PCTPOVALL_2017','MEDHHINC_2017']
poverty_df = poverty[columns]
poverty_df = poverty_df.rename(columns = {'PCTPOVALL_2017':'poverty_rate', 'MEDHHINC_2017': 'median_hh_income'})
print(poverty_df.shape)
poverty_df.head()
# Out:
# (3192, 4)
#         Area_Name State  poverty_rate median_hh_income
# 0  Autauga County    AL          13.4           58,343
# 1  Baldwin County    AL          10.1           56,607
# 2  Barbour County    AL          33.4           32,490
# 3     Bibb County    AL          20.2           45,795
# 4   Blount County    AL          12.8           48,253

# %%
# Trimming property tax dataset
columns = ['State','Abbreviation','Average effective property tax rate']
tax_df = proptax[columns]
tax_df.rename(columns = {'Average effective property tax rate':'property_tax_rate'},inplace=True)
print(tax_df.shape)
tax_df.head()
# Out:
# (51, 3)
#         State Abbreviation  property_tax_rate
# 0     Alabama           AL           0.372825
# 1      Alaska           AK           1.016092
# 2     Arizona           AZ           0.643978
# 3    Arkansas           AR           0.633284
# 4  California           CA           0.699057

# %%
# Trimming home prices dataset
columns = ['RegionName','State','SizeRank','2016-07','2016-08','2016-09','2016-10','2016-11','2016-12','2017-01','2017-02','2017-03','2017-04','2017-05','2017-06']
homes_df = homes[columns]

homes_df['avg_home_price'] = homes_df.iloc[:,3:].mean(axis=1)
homes_df.drop(['2016-07','2016-08','2016-09','2016-10','2016-11','2016-12','2017-01','2017-02','2017-03','2017-04','2017-05','2017-06'],axis=1,inplace=True)

print(homes_df.shape)
homes_df
# Out:
# (2839, 4)
# /Users/flatironschooldc2/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#               RegionName State  SizeRank  avg_home_price
# 0     Los Angeles County    CA         1   560333.416667
# 1            Cook County    IL         2   225118.333333
# 2          Harris County    TX         3   178261.166667
# 3        Maricopa County    AZ         4   242960.916667
# 4       San Diego County    CA         5   530174.833333
# ...                  ...   ...       ...             ...
# 2834        Camas County    ID      2835    89772.916667
# 2835      Daggett County    UT      2836   167053.250000
# 2836     Hinsdale County    CO      2837   320431.250000
# 2837      Mineral County    CO      2838   240151.750000
# 2838     San Juan County    CO      2839   244661.083333
#
# [2839 rows x 4 columns]

# %%
# Trimming the amazon warehouse dataset

# Obtaining county from lat./long
counties = []
for lat, long in zip(aws_loc.aw_lat, aws_loc.aw_long):
    location = geolocator.reverse(f"{lat},{long}", timeout=None)
    try:
        counties.append(location.raw['address']['county'])
    except:
        counties.append(np.nan)
# Out:
# /Users/flatironschooldc2/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning: `timeout=None` has been passed to a geocoder call. Using default geocoder timeout. In geopy 2.0 the behavior will be different: None will mean "no timeout" instead of "default geocoder timeout". Pass geopy.geocoders.base.DEFAULT_SENTINEL instead of None to get rid of this warning.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
aws_df = aws_loc[['aw_zip_str','aw_lat','aw_long','aw_coord','aw_city','aw_state','amazon_indicator','county']]
aws_df['county'] = counties
# Imputing 'Baltimore County' for 21224 zip code values
aws_df.loc[[62,63,64],'county'] = 'Baltimore County'
aws_df.drop('aw_city',axis=1,inplace=True)
# Out:
# (184, 8)
#    aw_zip_str     aw_lat     aw_long          aw_coord   aw_city aw_state  \
# 0       85043  33.433324 -112.207797  (33.43, -112.21)   Phoenix  Arizona
# 1       85338  33.412196 -112.421938  (33.41, -112.42)  Goodyear  Arizona
# 2       85043  33.431192 -112.156569  (33.43, -112.16)   Phoenix  Arizona
# 3       85043  33.448519 -112.221179  (33.45, -112.22)   Phoenix  Arizona
# 4       85043  33.431180 -112.159493  (33.43, -112.16)   Phoenix  Arizona
#
#    amazon_indicator           county
# 0                 1  Maricopa County
# 1                 1  Maricopa County
# 2                 1  Maricopa County
# 3                 1  Maricopa County
# 4                 1  Maricopa County

# %%
print(aws_df.shape)
aws_df.head()
# Out:
# (184, 7)
#    aw_zip_str     aw_lat     aw_long          aw_coord aw_state  \
# 0       85043  33.433324 -112.207797  (33.43, -112.21)  Arizona
# 1       85338  33.412196 -112.421938  (33.41, -112.42)  Arizona
# 2       85043  33.431192 -112.156569  (33.43, -112.16)  Arizona
# 3       85043  33.448519 -112.221179  (33.45, -112.22)  Arizona
# 4       85043  33.431180 -112.159493  (33.43, -112.16)  Arizona
#
#    amazon_indicator           county
# 0                 1  Maricopa County
# 1                 1  Maricopa County
# 2                 1  Maricopa County
# 3                 1  Maricopa County
# 4                 1  Maricopa County

# %%
# Obtain county from lat/long
# from geopy.geocoders import Nominatim
# geolocator = Nominatim()

# def get_counties(lat,long):
#     location = geolocator.reverse(f"{lat},{long}", timeout=None)
#     return location.raw['address']['county']
# Out:
# /Users/flatironschooldc2/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Using Nominatim with the default "geopy/1.20.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Trimming the walmart warehouse dataset

# Deleting zip-code for Puerto Rico
walmart_df = walmart_loc.drop(44)
walmart_df.reset_index(drop=True)

walmart_df.zip_code = walmart_df.zip_code.astype(str)
walmart_df.dtypes
# Out:
# zip_code        object
# wh_indicator     int64
# dtype: object

# %%
lats = []
longs = []
for i in walmart_df.zip_code:
    if len(i) == 5:
        loc = geolocator.geocode({"country": 'United States of America',"postalcode": i})
        lats.append(loc.latitude)
        longs.append(loc.longitude)
    else:
        loc = geolocator.geocode({"country": 'United States of America',"postalcode": '0'+i})
        lats.append(loc.latitude)
        longs.append(loc.longitude)

# %%
walmart_df['wh_lat'] = lats
walmart_df['wh_long'] = longs
walmart_df['wh_coord'] = list(zip(lats,longs))

walmart_df.head()
# Out:
#   zip_code  wh_indicator     wh_lat     wh_long  \
# 0    27302             1  36.085510  -79.242629
# 1    98421             1  47.248082 -122.406345
# 2    77535             1  30.044420  -94.889941
# 3    75115             1  32.611767  -96.857492
# 4    78130             1  29.695254  -98.111411
#
#                                    wh_coord
# 0   (36.08550952880476, -79.24262921827149)
# 1  (47.24808186295794, -122.40634483768773)
# 2        (30.044419650000002, -94.88994075)
# 3     (32.6117670212239, -96.8574916216362)
# 4    (29.69525418211604, -98.1114112958971)

# %%
location.raw['address']
# Out:
# {'house_number': '8576',
#  'road': 'Red Oak Street',
#  'hamlet': 'North Cucamonga',
#  'city': 'Rancho Cucamonga',
#  'county': 'San Bernardino County',
#  'state': 'California',
#  'postcode': '91730',
#  'country': 'United States of America',
#  'country_code': 'us'}

# %%
# Obtaining county from lat./long
counties = []
states = []
for lat, long in zip(walmart_df.wh_lat, walmart_df.wh_long):
    location = geolocator.reverse(f"{lat},{long}", timeout=None)
    try:
        counties.append(location.raw['address']['county'])
        states.append(location.raw['address']['state'])
    except:
        counties.append(np.nan)
        states.append(np.nan)
# Out:
# /Users/flatironschooldc2/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:5: DeprecationWarning: `timeout=None` has been passed to a geocoder call. Using default geocoder timeout. In geopy 2.0 the behavior will be different: None will mean "no timeout" instead of "default geocoder timeout". Pass geopy.geocoders.base.DEFAULT_SENTINEL instead of None to get rid of this warning.
#   """

# %%
walmart_df['county'] = counties
walmart_df['state'] = states
walmart_df = walmart_df[['zip_code','county','state','wh_lat','wh_long','wh_coord','wh_indicator']]
walmart_df.head()
# Out:
#   zip_code          county           state     wh_lat     wh_long  \
# 0    27302   Orange County  North Carolina  36.085510  -79.242629
# 1    98421   Pierce County      Washington  47.248082 -122.406345
# 2    77535  Liberty County           Texas  30.044420  -94.889941
# 3    75115   Dallas County           Texas  32.611767  -96.857492
# 4    78130    Comal County           Texas  29.695254  -98.111411
#
#                                    wh_coord  wh_indicator
# 0   (36.08550952880476, -79.24262921827149)             1
# 1  (47.24808186295794, -122.40634483768773)             1
# 2        (30.044419650000002, -94.88994075)             1
# 3     (32.6117670212239, -96.8574916216362)             1
# 4    (29.69525418211604, -98.1114112958971)             1

# %%
# Imputing 'James City County, VA' for 23185
# walmart_df.loc[[36],'county'] = 'James City County'
# walmart_df.loc[[36],'state'] = 'Virginia'

# %%
print(walmart_df.shape)
walmart_df.head()
# Out:
# (176, 7)
#   zip_code          county           state     wh_lat     wh_long  \
# 0    27302   Orange County  North Carolina  36.085510  -79.242629
# 1    98421   Pierce County      Washington  47.248082 -122.406345
# 2    77535  Liberty County           Texas  30.044420  -94.889941
# 3    75115   Dallas County           Texas  32.611767  -96.857492
# 4    78130    Comal County           Texas  29.695254  -98.111411
#
#                                    wh_coord  wh_indicator
# 0   (36.08550952880476, -79.24262921827149)             1
# 1  (47.24808186295794, -122.40634483768773)             1
# 2        (30.044419650000002, -94.88994075)             1
# 3     (32.6117670212239, -96.8574916216362)             1
# 4    (29.69525418211604, -98.1114112958971)             1

# %% [markdown]
# ## Merge datasets, and remove state level information

# %%
# drop rows with missing values
homes_df.dropna(inplace=True)
# Out:
# (2839, 5)
# /Users/flatironschooldc2/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# (2834, 5)

# %%
# Use homes_df as base dataset
homes_df['state_name'] = homes_df.State.map(inv_map)
# Out:
# /Users/flatironschooldc2/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Northern Mariana Islands':'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Palau': 'PW',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virgin Islands': 'VI',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY'
}

inv_map = {v: k for k, v in us_state_abbrev.items()}

# %%
homes_df.head()
# Out:
#            RegionName State  SizeRank  avg_home_price  state_name
# 0  Los Angeles County    CA         1   560333.416667  California
# 1         Cook County    IL         2   225118.333333    Illinois
# 2       Harris County    TX         3   178261.166667       Texas
# 3     Maricopa County    AZ         4   242960.916667     Arizona
# 4    San Diego County    CA         5   530174.833333  California

# %%
area_df.head()
# Out:
#            county    state  area_sq_mi
# 0   United States      NaN  3796742.23
# 1         Alabama      NaN    52420.07
# 2  Autauga County  Alabama      604.39
# 3  Baldwin County  Alabama     2027.31
# 4  Barbour County  Alabama      904.52

# %%
# merge with area dataset
df1 = pd.merge(homes_df, area_df, how='inner', left_on=['RegionName','state_name'], right_on=['county','state'])
df1.drop(['RegionName','State','state_name'],axis=1,inplace=True)
df1['state_abbrev'] = df1.state.map(us_state_abbrev)
df1 = df1[['county','state','state_abbrev','SizeRank','avg_home_price','area_sq_mi']]
df1.head()
# Out:
#                county       state state_abbrev  SizeRank  avg_home_price  \
# 0  Los Angeles County  California           CA         1   560333.416667
# 1         Cook County    Illinois           IL         2   225118.333333
# 2       Harris County       Texas           TX         3   178261.166667
# 3     Maricopa County     Arizona           AZ         4   242960.916667
# 4    San Diego County  California           CA         5   530174.833333
#
#    area_sq_mi
# 0     4750.94
# 1     1634.86
# 2     1777.48
# 3     9224.39
# 4     4525.68

# %%
# merge with unemployment dataset
df2 = pd.merge(df1, unemp_df, how='inner', left_on=['county','state_abbrev'], right_on=['county','state'])
df2.drop('state_y',axis=1,inplace=True)
df2.rename(columns = {'state_x':'state', 'SizeRank':'size_rank'},inplace=True)
df2.head()
# Out:
#                county       state state_abbrev  size_rank  avg_home_price  \
# 0  Los Angeles County  California           CA          1   560333.416667
# 1         Cook County    Illinois           IL          2   225118.333333
# 2       Harris County       Texas           TX          3   178261.166667
# 3     Maricopa County     Arizona           AZ          4   242960.916667
# 4    San Diego County  California           CA          5   530174.833333
#
#    area_sq_mi  unemployment_rate  unemployment_change
# 0     4750.94                4.8                 -7.7
# 1     1634.86                5.1                 -5.8
# 2     1777.48                5.1                 -3.2
# 3     9224.39                4.2                 -5.3
# 4     4525.68                4.0                 -6.8

# %%
# merge with education dataset
df3 = pd.merge(df2, educ_df, how='inner', left_on=['county','state_abbrev'], right_on=['Area name','State'])
df3.drop(['Area name', 'State'],axis=1,inplace=True)
print(df3.shape)
df3.head()
# Out:
# (2364, 12)
#                county       state state_abbrev  size_rank  avg_home_price  \
# 0  Los Angeles County  California           CA          1   560333.416667
# 1         Cook County    Illinois           IL          2   225118.333333
# 2       Harris County       Texas           TX          3   178261.166667
# 3     Maricopa County     Arizona           AZ          4   242960.916667
# 4    San Diego County  California           CA          5   530174.833333
#
#    area_sq_mi  unemployment_rate  unemployment_change  less_high_school  \
# 0     4750.94                4.8                 -7.7              21.8
# 1     1634.86                5.1                 -5.8              13.8
# 2     1777.48                5.1                 -3.2              19.5
# 3     9224.39                4.2                 -5.3              12.9
# 4     4525.68                4.0                 -6.8              13.3
#
#    high_school  college_or_associates  bachelors
# 0         20.7                   26.2       31.2
# 1         23.5                   25.5       37.2
# 2         23.3                   26.7       30.5
# 3         22.8                   32.9       31.4
# 4         18.6                   30.7       37.4

# %%
# merge with population dataset
df4 = pd.merge(df3, pop_df, how='inner', left_on=['county','state_abbrev'], right_on=['Area_Name','State'])
df4.drop(['Area_Name', 'State'],axis=1,inplace=True)
df4.head()
# Out:
#                county       state state_abbrev  size_rank  avg_home_price  \
# 0  Los Angeles County  California           CA          1   560333.416667
# 1         Cook County    Illinois           IL          2   225118.333333
# 2       Harris County       Texas           TX          3   178261.166667
# 3     Maricopa County     Arizona           AZ          4   242960.916667
# 4    San Diego County  California           CA          5   530174.833333
#
#    area_sq_mi  unemployment_rate  unemployment_change  less_high_school  \
# 0     4750.94                4.8                 -7.7              21.8
# 1     1634.86                5.1                 -5.8              13.8
# 2     1777.48                5.1                 -3.2              19.5
# 3     9224.39                4.2                 -5.3              12.9
# 4     4525.68                4.0                 -6.8              13.3
#
#    high_school  college_or_associates  bachelors  population  \
# 0         20.7                   26.2       31.2    10118759
# 1         23.5                   25.5       37.2     5204502
# 2         23.3                   26.7       30.5     4664159
# 3         22.8                   32.9       31.4     4329580
# 4         18.6                   30.7       37.4     3325468
#
#    int_migration_rate  net_migration_rate  pop_growth
# 0            3.456049           -5.558295    3.016829
# 1            3.551055           -9.067036    0.102632
# 2            7.640949           -2.082565   13.543191
# 3            2.284534           11.263849   13.185982
# 4            3.435935           -1.311985    7.158882

# %%
# merge with poverty dataset
df5 = pd.merge(df4, poverty_df, how='inner', left_on=['county','state_abbrev'], right_on=['Area_Name','State'])
df5.drop(['Area_Name', 'State'],axis=1,inplace=True)
# Convert to integer
df5['median_hh_income'] = df5.median_hh_income.apply(lambda x: int(x.replace(',','')))
df5.head()
# Out:
#                county       state state_abbrev  size_rank  avg_home_price  \
# 0  Los Angeles County  California           CA          1   560333.416667
# 1         Cook County    Illinois           IL          2   225118.333333
# 2       Harris County       Texas           TX          3   178261.166667
# 3     Maricopa County     Arizona           AZ          4   242960.916667
# 4    San Diego County  California           CA          5   530174.833333
#
#    area_sq_mi  unemployment_rate  unemployment_change  less_high_school  \
# 0     4750.94                4.8                 -7.7              21.8
# 1     1634.86                5.1                 -5.8              13.8
# 2     1777.48                5.1                 -3.2              19.5
# 3     9224.39                4.2                 -5.3              12.9
# 4     4525.68                4.0                 -6.8              13.3
#
#    high_school  college_or_associates  bachelors  population  \
# 0         20.7                   26.2       31.2    10118759
# 1         23.5                   25.5       37.2     5204502
# 2         23.3                   26.7       30.5     4664159
# 3         22.8                   32.9       31.4     4329580
# 4         18.6                   30.7       37.4     3325468
#
#    int_migration_rate  net_migration_rate  pop_growth  poverty_rate  \
# 0            3.456049           -5.558295    3.016829          14.9
# 1            3.551055           -9.067036    0.102632          14.6
# 2            7.640949           -2.082565   13.543191          15.9
# 3            2.284534           11.263849   13.185982          13.5
# 4            3.435935           -1.311985    7.158882          11.9
#
#    median_hh_income
# 0             64912
# 1             61401
# 2             58664
# 3             62221
# 4             76048

# %%
# merge with property tax dataset
df6 = pd.merge(df5, tax_df, how='inner', left_on=['state','state_abbrev'], right_on=['State','Abbreviation'])
df6.drop(['Abbreviation', 'State'],axis=1,inplace=True)
df6.head()
# Out:
#                   county       state state_abbrev  size_rank  avg_home_price  \
# 0     Los Angeles County  California           CA          1   560333.416667
# 1       San Diego County  California           CA          5   530174.833333
# 2          Orange County  California           CA          6   670382.666667
# 3       Riverside County  California           CA         11   341060.000000
# 4  San Bernardino County  California           CA         12   307173.166667
#
#    area_sq_mi  unemployment_rate  unemployment_change  less_high_school  \
# 0     4750.94                4.8                 -7.7              21.8
# 1     4525.68                4.0                 -6.8              13.3
# 2      948.07                3.5                 -6.2              15.3
# 3     7303.42                5.2                 -8.6              18.9
# 4    20104.83                4.9                 -8.6              20.8
#
#    high_school  college_or_associates  bachelors  population  \
# 0         20.7                   26.2       31.2    10118759
# 1         18.6                   30.7       37.4     3325468
# 2         17.3                   28.3       39.1     3179950
# 3         26.4                   33.2       21.5     2417224
# 4         26.2                   33.2       19.8     2153203
#
#    int_migration_rate  net_migration_rate  pop_growth  poverty_rate  \
# 0            3.456049           -5.558295    3.016829          14.9
# 1            3.435935           -1.311985    7.158882          11.9
# 2            3.266434           -2.430615    5.416470          11.5
# 3            0.807951            8.932883    9.791375          12.9
# 4            0.721653            1.506749    5.502104          16.0
#
#    median_hh_income  property_tax_rate
# 0             64912           0.699057
# 1             76048           0.699057
# 2             86031           0.699057
# 3             63776           0.699057
# 4             60270           0.699057

# %%
df6.head()
# df6.isnull().sum()
# Out:
#                   county       state state_abbrev  size_rank  avg_home_price  \
# 0     Los Angeles County  California           CA          1   560333.416667
# 1       San Diego County  California           CA          5   530174.833333
# 2          Orange County  California           CA          6   670382.666667
# 3       Riverside County  California           CA         11   341060.000000
# 4  San Bernardino County  California           CA         12   307173.166667
#
#    area_sq_mi  unemployment_rate  unemployment_change  less_high_school  \
# 0     4750.94                4.8                 -7.7              21.8
# 1     4525.68                4.0                 -6.8              13.3
# 2      948.07                3.5                 -6.2              15.3
# 3     7303.42                5.2                 -8.6              18.9
# 4    20104.83                4.9                 -8.6              20.8
#
#    high_school  college_or_associates  bachelors  population  \
# 0         20.7                   26.2       31.2    10118759
# 1         18.6                   30.7       37.4     3325468
# 2         17.3                   28.3       39.1     3179950
# 3         26.4                   33.2       21.5     2417224
# 4         26.2                   33.2       19.8     2153203
#
#    int_migration_rate  net_migration_rate  pop_growth  poverty_rate  \
# 0            3.456049           -5.558295    3.016829          14.9
# 1            3.435935           -1.311985    7.158882          11.9
# 2            3.266434           -2.430615    5.416470          11.5
# 3            0.807951            8.932883    9.791375          12.9
# 4            0.721653            1.506749    5.502104          16.0
#
#    median_hh_income  property_tax_rate
# 0             64912           0.699057
# 1             76048           0.699057
# 2             86031           0.699057
# 3             63776           0.699057
# 4             60270           0.699057

# %%
# merge with amazon warehouse dataset
aws_df2 = aws_df[['aw_state','county','amazon_indicator']].drop_duplicates().reset_index(drop=True)
df7 = pd.merge(df6, aws_df2, how='left', left_on=['state','county'], right_on=['aw_state','county'])
df7.drop('aw_state',axis=1,inplace=True)
df7.head()
# Out:
#                   county       state state_abbrev  size_rank  avg_home_price  \
# 0     Los Angeles County  California           CA          1   560333.416667
# 1       San Diego County  California           CA          5   530174.833333
# 2          Orange County  California           CA          6   670382.666667
# 3       Riverside County  California           CA         11   341060.000000
# 4  San Bernardino County  California           CA         12   307173.166667
#
#    area_sq_mi  unemployment_rate  unemployment_change  less_high_school  \
# 0     4750.94                4.8                 -7.7              21.8
# 1     4525.68                4.0                 -6.8              13.3
# 2      948.07                3.5                 -6.2              15.3
# 3     7303.42                5.2                 -8.6              18.9
# 4    20104.83                4.9                 -8.6              20.8
#
#    high_school  college_or_associates  bachelors  population  \
# 0         20.7                   26.2       31.2    10118759
# 1         18.6                   30.7       37.4     3325468
# 2         17.3                   28.3       39.1     3179950
# 3         26.4                   33.2       21.5     2417224
# 4         26.2                   33.2       19.8     2153203
#
#    int_migration_rate  net_migration_rate  pop_growth  poverty_rate  \
# 0            3.456049           -5.558295    3.016829          14.9
# 1            3.435935           -1.311985    7.158882          11.9
# 2            3.266434           -2.430615    5.416470          11.5
# 3            0.807951            8.932883    9.791375          12.9
# 4            0.721653            1.506749    5.502104          16.0
#
#    median_hh_income  property_tax_rate  amazon_indicator
# 0             64912           0.699057               NaN
# 1             76048           0.699057               NaN
# 2             86031           0.699057               NaN
# 3             63776           0.699057               1.0
# 4             60270           0.699057               1.0

# %%
walmart_df2 = walmart_df[['county','state','wh_indicator']].drop_duplicates().reset_index(drop=True)
walmart_df2
# Out:
#                     county           state  wh_indicator
# 0            Orange County  North Carolina             1
# 1            Pierce County      Washington             1
# 2           Liberty County           Texas             1
# 3            Dallas County           Texas             1
# 4             Comal County           Texas             1
# 5        Lackawanna County    Pennsylvania             1
# 6             Stark County            Ohio             1
# 7         Merrimack County   New Hampshire             1
# 8       Mecklenburg County  North Carolina             1
# 9           Forrest County     Mississippi             1
# 10         Hennepin County       Minnesota             1
# 11            Wayne County        Michigan             1
# 12       Washington County        Maryland             1
# 13        Wyandotte County          Kansas             1
# 14          Hancock County         Indiana             1
# 15             Will County        Illinois             1
# 16          Carroll County         Georgia             1
# 17             Polk County         Florida             1
# 18            Duval County         Florida             1
# 19          Larimer County        Colorado             1
# 20   San Bernardino County      California             1
# 21             Yolo County      California             1
# 22         Maricopa County         Arizona             1
# 23            White County        Arkansas             1
# 24           Shelby County       Tennessee             1
# 25           Monroe County    Pennsylvania             1
# 26         Cabarrus County  North Carolina             1
# 27             Lake County         Indiana             1
# 28            Boone County        Illinois             1
# 29           DeKalb County         Georgia             1
# 30      Los Angeles County      California             1
# 31        Riverside County      California             1
# 32           Benton County        Arkansas             1
# 33       James City County        Virginia             1
# 34           Harris County           Texas             1
# 35          Shawnee County          Kansas             1
# 36          Bulloch County         Georgia             1
# 37           Mobile County         Alabama             1
# 38            Henry County         Georgia             1
# 39         Cherokee County        Oklahoma             1
# 40         McLennan County           Texas             1
# 41      Spartanburg County  South Carolina             1
# 42           Fulton County        New York             1
# 43            Clark County          Nevada             1
# 44             Tift County         Georgia             1
# 45            Kings County      California             1
# 46       Washington County        Arkansas             1
# 47       Montgomery County         Indiana             1
# 48             Webb County           Texas             1
# 49             Cook County        Illinois             1
# 50     Hillsborough County         Florida             1
# 51          Tarrant County           Texas             1
# 52      Northampton County    Pennsylvania             1
# 53            Bronx County        New York             1
# 54          Bullitt County        Kentucky             1
# 55        Hendricks County         Indiana             1
# 56           Fulton County         Georgia             1
# 57          Madison County        Arkansas             1
# 58        Sebastian County        Arkansas             1
# 59       Washington County            Utah             1
# 60         Anderson County           Texas             1
# 61          Laurens County  South Carolina             1
# 62        Schoharie County        New York             1
# 63           Putnam County         Indiana             1
# 64          Cullman County         Alabama             1
# 65           Tulare County      California             1
# 66           Tehama County      California             1
# 67             Kent County        Delaware             1
# 68          Alachua County         Florida             1
# 69         Hernando County         Florida             1
# 70        St. Lucie County         Florida             1
# 71           Coffee County         Georgia             1
# 72            Troup County         Georgia             1
# 73            Henry County            Iowa             1
# 74           Bureau County        Illinois             1
# 75          Jackson County         Indiana             1
# 76         Franklin County          Kansas             1
# 77        Christian County        Kentucky             1
# 78       St. Landry Parish       Louisiana             1
# 79           Branch County        Michigan             1
# 80           Phelps County        Missouri             1
# 81          Lincoln County     Mississippi             1
# 82       Cumberland County  North Carolina             1
# 83        Cleveland County  North Carolina             1
# 84       Rockingham County   New Hampshire             1
# 85           Oneida County        New York             1
# 86         Franklin County            Ohio             1
# 87         Umatilla County          Oregon             1
# 88       Clearfield County    Pennsylvania             1
# 89           Greene County       Tennessee             1
# 90             Hale County           Texas             1
# 91           Denton County           Texas             1
# 92           Austin County           Texas             1
# 93           Tooele County            Utah             1
# 94       Rockingham County        Virginia             1
# 95        Dinwiddie County        Virginia             1
# 96            Dodge County       Wisconsin             1
# 97             Dunn County       Wisconsin             1
# 98             Pike County         Alabama             1
# 99              Lee County         Alabama             1
# 100         Johnson County        Arkansas             1
# 101           Pinal County         Arizona             1
# 102          DeSoto County         Florida             1
# 103           Baker County         Florida             1
# 104          Walton County         Georgia             1
# 105        Richland County        Illinois             1
# 106       Whiteside County        Illinois             1
# 107           Grant County         Indiana             1
# 108          Laurel County        Kentucky             1
# 109      Tangipahoa Parish       Louisiana             1
# 110    Androscoggin County           Maine             1
# 111            Cass County        Missouri             1
# 112           Union County     Mississippi             1
# 113         Lincoln County        Nebraska             1
# 114        Valencia County      New Mexico             1
# 115          Washoe County          Nevada             1
# 116         Fayette County            Ohio             1
# 117       Jefferson County            Ohio             1
# 118      Washington County        Oklahoma             1
# 119          Garvin County        Oklahoma             1
# 120         Bedford County    Pennsylvania             1
# 121      Schuylkill County    Pennsylvania             1
# 122    Chesterfield County  South Carolina             1
# 123         Bedford County       Tennessee             1
# 124         Johnson County           Texas             1
# 125      Montgomery County           Texas             1
# 126            Bell County           Texas             1
# 127       Box Elder County            Utah             1
# 128          Louisa County        Virginia             1
# 129          Yakima County      Washington             1
# 130          Monroe County       Wisconsin             1
# 131         Laramie County         Wyoming             1
# 132          Merced County      California             1
# 133           Adams County        Colorado             1
# 134          DeKalb County         Indiana             1
# 135        Randolph County        Missouri             1
# 136           Vance County  North Carolina             1
# 137         Kaufman County           Texas             1
# 138      Blue Earth County       Minnesota             1

# %%
# merge with walmart warehouse dataset
df8 = pd.merge(df7, walmart_df2, how='left', left_on=['state','county'], right_on=['state','county'])
df8.rename(columns = {'wh_indicator':'walmart_indicator'},inplace=True)
df8.head()
# Out:
#                   county       state state_abbrev  size_rank  avg_home_price  \
# 0     Los Angeles County  California           CA          1   560333.416667
# 1       San Diego County  California           CA          5   530174.833333
# 2          Orange County  California           CA          6   670382.666667
# 3       Riverside County  California           CA         11   341060.000000
# 4  San Bernardino County  California           CA         12   307173.166667
#
#    area_sq_mi  unemployment_rate  unemployment_change  less_high_school  \
# 0     4750.94                4.8                 -7.7              21.8
# 1     4525.68                4.0                 -6.8              13.3
# 2      948.07                3.5                 -6.2              15.3
# 3     7303.42                5.2                 -8.6              18.9
# 4    20104.83                4.9                 -8.6              20.8
#
#    high_school  ...  bachelors  population  int_migration_rate  \
# 0         20.7  ...       31.2    10118759            3.456049
# 1         18.6  ...       37.4     3325468            3.435935
# 2         17.3  ...       39.1     3179950            3.266434
# 3         26.4  ...       21.5     2417224            0.807951
# 4         26.2  ...       19.8     2153203            0.721653
#
#    net_migration_rate  pop_growth  poverty_rate  median_hh_income  \
# 0           -5.558295    3.016829          14.9             64912
# 1           -1.311985    7.158882          11.9             76048
# 2           -2.430615    5.416470          11.5             86031
# 3            8.932883    9.791375          12.9             63776
# 4            1.506749    5.502104          16.0             60270
#
#    property_tax_rate  amazon_indicator  walmart_indicator
# 0           0.699057               NaN                1.0
# 1           0.699057               NaN                NaN
# 2           0.699057               NaN                NaN
# 3           0.699057               1.0                1.0
# 4           0.699057               1.0                1.0
#
# [5 rows x 21 columns]

# %% [markdown]
# - clean indicator variables
# - calculate pop. density column and delete population/land area columns
# - feature engineer/eliminate 1 category variables (education level)
# - get lat./long. of each county

# %%
# impute 0 values for 'NaN'
def indicator_clean(x):
    if math.isnan(x) == True:
        return 0
    else:
        return 1
df8['amazon_indicator'] = df8.amazon_indicator.apply(indicator_clean)
df8.head()
# Out:
#                   county       state state_abbrev  size_rank  avg_home_price  \
# 0     Los Angeles County  California           CA          1   560333.416667
# 1       San Diego County  California           CA          5   530174.833333
# 2          Orange County  California           CA          6   670382.666667
# 3       Riverside County  California           CA         11   341060.000000
# 4  San Bernardino County  California           CA         12   307173.166667
#
#    area_sq_mi  unemployment_rate  unemployment_change  less_high_school  \
# 0     4750.94                4.8                 -7.7              21.8
# 1     4525.68                4.0                 -6.8              13.3
# 2      948.07                3.5                 -6.2              15.3
# 3     7303.42                5.2                 -8.6              18.9
# 4    20104.83                4.9                 -8.6              20.8
#
#    high_school  ...  bachelors  population  int_migration_rate  \
# 0         20.7  ...       31.2    10118759            3.456049
# 1         18.6  ...       37.4     3325468            3.435935
# 2         17.3  ...       39.1     3179950            3.266434
# 3         26.4  ...       21.5     2417224            0.807951
# 4         26.2  ...       19.8     2153203            0.721653
#
#    net_migration_rate  pop_growth  poverty_rate  median_hh_income  \
# 0           -5.558295    3.016829          14.9             64912
# 1           -1.311985    7.158882          11.9             76048
# 2           -2.430615    5.416470          11.5             86031
# 3            8.932883    9.791375          12.9             63776
# 4            1.506749    5.502104          16.0             60270
#
#    property_tax_rate  amazon_indicator  walmart_indicator
# 0           0.699057                 0                1.0
# 1           0.699057                 0                NaN
# 2           0.699057                 0                NaN
# 3           0.699057                 1                1.0
# 4           0.699057                 1                1.0
#
# [5 rows x 21 columns]

# %%
df8['walmart_indicator'] = df8.walmart_indicator.apply(indicator_clean)
df8.head()
# Out:
#                   county       state state_abbrev  size_rank  avg_home_price  \
# 0     Los Angeles County  California           CA          1   560333.416667
# 1       San Diego County  California           CA          5   530174.833333
# 2          Orange County  California           CA          6   670382.666667
# 3       Riverside County  California           CA         11   341060.000000
# 4  San Bernardino County  California           CA         12   307173.166667
#
#    area_sq_mi  unemployment_rate  unemployment_change  less_high_school  \
# 0     4750.94                4.8                 -7.7              21.8
# 1     4525.68                4.0                 -6.8              13.3
# 2      948.07                3.5                 -6.2              15.3
# 3     7303.42                5.2                 -8.6              18.9
# 4    20104.83                4.9                 -8.6              20.8
#
#    high_school  ...  bachelors  population  int_migration_rate  \
# 0         20.7  ...       31.2    10118759            3.456049
# 1         18.6  ...       37.4     3325468            3.435935
# 2         17.3  ...       39.1     3179950            3.266434
# 3         26.4  ...       21.5     2417224            0.807951
# 4         26.2  ...       19.8     2153203            0.721653
#
#    net_migration_rate  pop_growth  poverty_rate  median_hh_income  \
# 0           -5.558295    3.016829          14.9             64912
# 1           -1.311985    7.158882          11.9             76048
# 2           -2.430615    5.416470          11.5             86031
# 3            8.932883    9.791375          12.9             63776
# 4            1.506749    5.502104          16.0             60270
#
#    property_tax_rate  amazon_indicator  walmart_indicator
# 0           0.699057                 0                  1
# 1           0.699057                 0                  0
# 2           0.699057                 0                  0
# 3           0.699057                 1                  1
# 4           0.699057                 1                  1
#
# [5 rows x 21 columns]

# %%
# make an overall warehouse indicator column
def indicator(row):
    if row.amazon_indicator ==1 or row.walmart_indicator ==1:
        return 1
    else:
        return 0

df8['warehouse_indicator'] = df8.apply(indicator, axis=1)
df8.head()
# Out:
#                   county       state state_abbrev  size_rank  avg_home_price  \
# 0     Los Angeles County  California           CA          1   560333.416667
# 1       San Diego County  California           CA          5   530174.833333
# 2          Orange County  California           CA          6   670382.666667
# 3       Riverside County  California           CA         11   341060.000000
# 4  San Bernardino County  California           CA         12   307173.166667
#
#    area_sq_mi  unemployment_rate  unemployment_change  less_high_school  \
# 0     4750.94                4.8                 -7.7              21.8
# 1     4525.68                4.0                 -6.8              13.3
# 2      948.07                3.5                 -6.2              15.3
# 3     7303.42                5.2                 -8.6              18.9
# 4    20104.83                4.9                 -8.6              20.8
#
#    high_school  ...  population  int_migration_rate  net_migration_rate  \
# 0         20.7  ...    10118759            3.456049           -5.558295
# 1         18.6  ...     3325468            3.435935           -1.311985
# 2         17.3  ...     3179950            3.266434           -2.430615
# 3         26.4  ...     2417224            0.807951            8.932883
# 4         26.2  ...     2153203            0.721653            1.506749
#
#    pop_growth  poverty_rate  median_hh_income  property_tax_rate  \
# 0    3.016829          14.9             64912           0.699057
# 1    7.158882          11.9             76048           0.699057
# 2    5.416470          11.5             86031           0.699057
# 3    9.791375          12.9             63776           0.699057
# 4    5.502104          16.0             60270           0.699057
#
#    amazon_indicator  walmart_indicator  warehouse_indicator
# 0                 0                  1                    1
# 1                 0                  0                    0
# 2                 0                  0                    0
# 3                 1                  1                    1
# 4                 1                  1                    1
#
# [5 rows x 22 columns]

# %%
# 7% of county dataset have a warehouse
df8.warehouse_indicator.value_counts(normalize=True)
# Out:
# 0    0.928481
# 1    0.071519
# Name: warehouse_indicator, dtype: float64

# %%
df8.rename(columns = {'warehouse_indicator':'warehouse_target'},inplace=True)

# %%
df8.head()
# Out:
#                   county       state state_abbrev  size_rank  avg_home_price  \
# 0     Los Angeles County  California           CA          1   560333.416667
# 1       San Diego County  California           CA          5   530174.833333
# 2          Orange County  California           CA          6   670382.666667
# 3       Riverside County  California           CA         11   341060.000000
# 4  San Bernardino County  California           CA         12   307173.166667
#
#    area_sq_mi  unemployment_rate  unemployment_change  less_high_school  \
# 0     4750.94                4.8                 -7.7              21.8
# 1     4525.68                4.0                 -6.8              13.3
# 2      948.07                3.5                 -6.2              15.3
# 3     7303.42                5.2                 -8.6              18.9
# 4    20104.83                4.9                 -8.6              20.8
#
#    high_school  college_or_associates  bachelors  population  \
# 0         20.7                   26.2       31.2    10118759
# 1         18.6                   30.7       37.4     3325468
# 2         17.3                   28.3       39.1     3179950
# 3         26.4                   33.2       21.5     2417224
# 4         26.2                   33.2       19.8     2153203
#
#    int_migration_rate  net_migration_rate  pop_growth  poverty_rate  \
# 0            3.456049           -5.558295    3.016829          14.9
# 1            3.435935           -1.311985    7.158882          11.9
# 2            3.266434           -2.430615    5.416470          11.5
# 3            0.807951            8.932883    9.791375          12.9
# 4            0.721653            1.506749    5.502104          16.0
#
#    median_hh_income  property_tax_rate  amazon_indicator  walmart_indicator  \
# 0             64912           0.699057                 0                  1
# 1             76048           0.699057                 0                  0
# 2             86031           0.699057                 0                  0
# 3             63776           0.699057                 1                  1
# 4             60270           0.699057                 1                  1
#
#    warehouse_target  pop_density
# 0                 1  2129.843568
# 1                 0   734.799632
# 2                 0  3354.129969
# 3                 1   330.971517
# 4                 1   107.098792

# %%
# Create population density column
df8['pop_density'] = df8.population/df8.area_sq_mi

# %%
# Add lat./long. for each county
# timed out due to too many requests
lats = []
longs = []
for county, state in zip(df8.county, df8.state):
    loc = geolocator.geocode({"country": 'United States of America',"state": state,"county": county})
    lats.append(loc.latitude)
    longs.append(loc.longitude)

# %%
df6['latitude'] = lats
df6['longitude'] = longs

# %%
df8.to_csv('data/retail_warehouses.csv')
